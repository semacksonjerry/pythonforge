# %% [markdown]
# # What are Conditional Statements in Python?

# %% [markdown]
# Conditional Statements in Python perform different computations or actions depending on whether a specific Boolean constraint evaluates to true or false.
#
#  They let a program make decisions and follow different paths instead of running every line in sequence. In Python, conditional statements are handled by the if statement and its companions: else, elif, and nested if.

# %% [markdown]
# # What is Python If Statement?

# %% [markdown]
# The Python if statement is used for decision-making operations. It contains a body of code that runs only when the condition given in the if statement is true. If the condition is false, the optional else statement runs instead, holding the code for the else condition.
#
# When you want to act on one condition while another is not true, you use the Python if-else statement.

# %% [markdown]
# # Python if Statement Syntax:
#
# ## Python `if...else` Statement Syntax
#
# The basic syntax of an `if...else` statement in Python is:
#
# ```python
# if expression:
#     statement
# else:
#     statement

# %% [markdown]
# ![If-Then Flowchart](../../assets/if_then_flowchart.png)

# %%
x = 0
y = 5

# %%
if x < y:
    print('yes')

# %%
number = 15
if number > 0:
  print("The number is positive")

# %% [markdown]
# # Indentation

# %% [markdown]
# Python relies on indentation (whitespace at the beginning of a line) to define scope in the code. Other programming languages often use curly-brackets for this purpose.

# %%
a = 33
b = 200
if b > a:
print("b is greater than a")

# %% [markdown]
# # Multiple Statements in If Block
#
# You can have multiple statements inside an if block. All statements must be indented at the same level.

# %% [markdown]
# Python follows a convention known as the off-side rule, a term coined by British computer scientist Peter J. Landin. (The term is taken from the offside law in association football.) Languages that adhere to the off-side rule define blocks by indentation.

# %% [markdown]
# In a Python program, contiguous statements that are indented to the same level are considered to be part of the same block.

# %% [markdown]
# ```python
# if <expr>:
#     <statement>
#     <statement>
#
#     ...
#     <statement>
# <following_statement>

# %%
age = 20
if age >= 18:
  print("You are an adult")
  print("You can vote")
  print("You have full legal rights")

# %%
if 'foo' in ['bar', 'baz', 'qux']:
    print('Expression was true')
    print('Executing statement in suite')
    print('...')
    print('Done.')
print('After conditional')

# %% [markdown]
# # What Happens When the “if” Condition Is Not Met
#
# When the condition is false and no else branch exists, the indented code is skipped entirely.

# %%
def main():
    x, y = 78, 4
    if(x < y):
        st = "x is less than y"
    print(st)


main()

# %% [markdown]
# # How to Use the “else” Condition
#
#
# To avoid the error above, you can add an else condition. The else condition is used when you have to judge one statement on the basis of another. If one condition is false, the else block provides an alternative path so the program still produces a result.

# %%
def main():
    x, y = 8, 4
    if(x < y):
        st = "x is less than y"
    else:
        st = "x is greater than y"
    print(st)

if __name__ == "__main__":
    main()

# %% [markdown]
# # When the “else” Condition Does Not Work
#
# The else condition will not always give you the desired result. It can print the wrong output when there is a flaw in the program logic. This usually happens when you have to justify more than two statements or conditions in a program.

# %%
def main():
    x, y = 8, 8
    if(x < y):
        st = "x is less than y"
    else:
        st = "x is greater than y"
    print(st)

if __name__ == "__main__":
    main()

# %% [markdown]
# Here both variables are the same (8, 8), yet the program output is “x is greater than y,” which is WRONG. This happens because the program checks the first condition (the if condition), and when it fails, it prints the second condition (the else condition) as the default.

# %% [markdown]
# # How to Use the “elif” Condition
#
# To correct the previous error made by the else condition, we can use the elif statement.
#
# By using the elif condition, you tell the program to test a third possibility when the first condition is false.
#
# You can chain multiple elif conditions to check for fourth, fifth, and further possibilities in your code.

# %%
def main():
    x, y = 8, 8
    if(x < y):
        st = "x is less than y"
    elif(x == y):
        st = "x is same as y"
    else:
        st = "x is greater than y"
    print(st)

if __name__ == "__main__":
    main()

# %% [markdown]
# # How to Execute a Conditional Statement With Minimal Code / Python ternary conditional expression

# %% [markdown]
# # Syntax:
#
# `value_if_true if condition else value_if_false`

# %% [markdown]
# It means:
#
#         If the condition is True, use value_if_true.
#
#         Otherwise, use value_if_false.

# %% [markdown]
# ```python
# if condition:
#     result = value_if_true
# else:
#     result = value_if_false
# ```

# %%
age = 20

if age >= 18:
    status = "Adult"
else:
    status = "Minor"

print(status)

# %%
age = 20

status = "Adult" if age >= 18 else "Minor"

print(status)

# %%
def main():
    x, y = 10, 8
    st = "x is less than y" if (x < y) else "x is greater than or equal to y"
    print(st)

if __name__ == "__main__":
    main()

# %% [markdown]
# # Python Nested if Statement
#
#
# A nested if statement places one if statement inside another, which is useful when a decision depends on a second condition.

# %% [markdown]
# # Example
#
#  The following example demonstrates a nested if statement in Python that calculates shipping cost based on country and order total.

# %%
total = 100
# country = "US"
country = "AU"

if country == "US":
    if total <= 50:
        print("Shipping Cost is $50")
    elif total <= 100:
        print("Shipping Cost is $25")
    elif total <= 150:
        print("Shipping Cost is $5")
    else:
        print("FREE")

if country == "AU":
    if total <= 50:
        print("Shipping Cost is $100")
    else:
        print("FREE")

# %% [markdown]
# Uncomment Line 2 in the code above, comment out Line 3, and run the code again to see how the output changes for a different country.

# %% [markdown]
# # Switch Case Statement in Python

# %% [markdown]
# A switch statement is a multiway branch statement that compares the value of a variable against the values specified in case statements.

# %% [markdown]
# # History
#
# For many years, the Python language did not have a switch statement, so developers implemented the same behavior with Python `dictionary` mapping.

# %%
def switch_example(argument):
    switcher = {
        0: "This is Case Zero",
        1: "This is Case One",
        2: "This is Case Two",
    }
    return switcher.get(argument, "nothing")

if __name__ == "__main__":
    argument = 1
    print(switch_example(argument))

# %% [markdown]
# # Switch Case With match (Python 3.10 and Later)

# %% [markdown]
# Since Python 3.10 (released in October 2021), Python provides a native match-case statement, known as structural pattern matching. It offers a clean, readable alternative to long elif chains and the dictionary approach shown above.

# %%
def switch_example(argument):
    match argument:
        case 0:
            return "This is Case Zero"
        case 1:
            return "This is Case One"
        case 2:
            return "This is Case Two"
        case _:
            return "nothing"

if __name__ == "__main__":
    print(switch_example(1))

# %% [markdown]
# The underscore (_) acts as the default case, matching any value not handled by the earlier cases, just like the default in a traditional switch statement.

# %% [markdown]
# # Python Conditional Statements
#
# | Statement | Purpose | When to Use |
# |-----------|---------|-------------|
# | `if` | Runs a block of code when a condition is `True`. | When you need a single yes/no decision. |
# | `if...else` | Executes one block if the condition is `True`, otherwise executes another block. | When there are two mutually exclusive outcomes. |
# | `elif` | Tests additional conditions after an `if` statement if previous conditions are `False`. | When there are three or more possible outcomes. |
# | Nested `if` | Places one `if` statement inside another `if` statement. | When a decision depends on another condition being checked first. |
# | Ternary (Conditional Expression) | Condenses an `if...else` statement into a single line. | When assigning a value based on a simple condition. |
# | `match-case` | Matches a value against multiple patterns or cases. *(Available in Python 3.10+)* | When selecting one action from many possible options. |
#
# ## Summary
#
# - **`if`** → Check one condition.
# - **`if...else`** → Choose between two outcomes.
# - **`elif`** → Check multiple conditions in order.
# - **Nested `if`** → Check a condition inside another condition.
# - **Ternary** → Write a simple `if...else` in one line.
# - **`match-case`** → Compare one value against many possible cases.
