# %% [markdown]
# # Working with Strings

# %% [markdown]
# # Python - Format - Strings

# %% [markdown]
# As we learned in the Python Variables chapter, we cannot combine strings and numbers like this:

# %%
age = 36
#This will produce an error:
txt = "My name is John, I am " + age
print(txt)

# %% [markdown]
# But we can combine strings and numbers by using f-strings or the format() method!

# %% [markdown]
# # F-Strings
#
# F-String was introduced in Python 3.6, and is now the preferred way of formatting strings.
#
# To specify a string as an f-string, simply put an f in front of the string literal, and add curly brackets {} as placeholders for variables and other operations.

# %%
age = 36
txt = f"My name is John, I am {age}"
print(txt)

# %% [markdown]
# # Placeholders and Modifiers
# A placeholder can contain variables, operations, functions, and modifiers to format the value.

# %%
price = 59
txt = f"The price is {price} dollars"
print(txt)

# %% [markdown]
# A placeholder can include a modifier to format the value.
#
# A modifier is included by adding a colon : followed by a legal formatting type, like .2f which means fixed point number with 2 decimals:

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)

# %% [markdown]
# #  Escape Characters

# %% [markdown]
# To insert characters that are illegal in a string, use an escape character.
#
# An escape character is a backslash \ followed by the character you want to insert.
#
# An example of an illegal character is a double quote inside a string that is surrounded by double quotes:

# %%
txt = "We are the so-called "Vikings" from the north."

# %% [markdown]
# To fix this problem, use the escape character \":

# %%
txt = "We are the so-called \"Vikings\" from the north."
print(txt)

# %% [markdown]
# ## Python Escape Sequences
#
# | Code | Meaning |
# |------|---------|
# | `\'` | Single Quote |
# | `\\` | Backslash |
# | `\n` | New Line |
# | `\r` | Carriage Return |
# | `\t` | Tab |
# | `\b` | Backspace |
# | `\f` | Form Feed |
# | `\ooo` | Character with Octal Value |
# | `\xhh` | Character with Hexadecimal Value |
#
# ---

# %% [markdown]
# ## Example

# %%
print("Hello\nWorld")
print("Hello\tWorld")
print("I\'m learning Python")
print("This is a backslash: \\")

# %% [markdown]
# # String Methods
#
# Python has a set of built-in methods that you can use on strings.
#
# Note: All string methods return new values. They do not change the original string.

# %% [markdown]
# ## Python String Methods
#
# | Method | Description |
# |---------|-------------|
# | `capitalize()` | Converts the first character to upper case |
# | `casefold()` | Converts string into lower case |
# | `center()` | Returns a centered string |
# | `count()` | Returns the number of times a specified value occurs in a string |
# | `encode()` | Returns an encoded version of the string |
# | `endswith()` | Returns `True` if the string ends with the specified value |
# | `expandtabs()` | Sets the tab size of the string |
# | `find()` | Searches the string for a specified value and returns the position where it was found |
# | `format()` | Formats specified values in a string |
# | `format_map()` | Formats specified values in a string |
# | `index()` | Searches the string for a specified value and returns the position where it was found |
# | `isalnum()` | Returns `True` if all characters in the string are alphanumeric |
# | `isalpha()` | Returns `True` if all characters in the string are alphabetic |
# | `isascii()` | Returns `True` if all characters in the string are ASCII characters |
# | `isdecimal()` | Returns `True` if all characters in the string are decimal numbers |
# | `isdigit()` | Returns `True` if all characters in the string are digits |
# | `isidentifier()` | Returns `True` if the string is a valid identifier |
# | `islower()` | Returns `True` if all characters in the string are lower case |
# | `isnumeric()` | Returns `True` if all characters in the string are numeric |
# | `isprintable()` | Returns `True` if all characters in the string are printable |
# | `isspace()` | Returns `True` if all characters in the string are whitespace characters |
# | `istitle()` | Returns `True` if the string follows title case rules |
# | `isupper()` | Returns `True` if all characters in the string are upper case |
# | `join()` | Joins the elements of an iterable into a string |
# | `ljust()` | Returns a left-justified version of the string |
# | `lower()` | Converts a string into lower case |
# | `lstrip()` | Returns a left-trimmed version of the string |
# | `maketrans()` | Returns a translation table to be used in translations |
# | `partition()` | Returns a tuple where the string is split into three parts |
# | `replace()` | Returns a string where a specified value is replaced with another value |
# | `rfind()` | Searches the string for a specified value and returns the last position where it was found |
# | `rindex()` | Searches the string for a specified value and returns the last position where it was found |
# | `rjust()` | Returns a right-justified version of the string |
# | `rpartition()` | Returns a tuple where the string is split into three parts |
# | `rsplit()` | Splits the string at the specified separator and returns a list |
# | `rstrip()` | Returns a right-trimmed version of the string |
# | `split()` | Splits the string at the specified separator and returns a list |
# | `splitlines()` | Splits the string at line breaks and returns a list |
# | `startswith()` | Returns `True` if the string starts with the specified value |
# | `strip()` | Returns a trimmed version of the string |
# | `swapcase()` | Swaps cases: lower case becomes upper case and vice versa |
# | `title()` | Converts the first character of each word to upper case |
# | `translate()` | Returns a translated string |
# | `upper()` | Converts a string into upper case |
# | `zfill()` | Fills the string with zeros (`0`) at the beginning |

# %% [markdown]
# # Commonly Used Python String Methods
#
# These are some of the most important string methods that every Python beginner should know.
#
# | Method | Description | Example |
# |---------|-------------|---------|
# | `upper()` | Converts all characters to uppercase | `"hello".upper()` → `'HELLO'` |
# | `lower()` | Converts all characters to lowercase | `"HELLO".lower()` → `'hello'` |
# | `capitalize()` | Converts the first character to uppercase | `"python".capitalize()` → `'Python'` |
# | `title()` | Converts the first character of each word to uppercase | `"python programming".title()` → `'Python Programming'` |
# | `strip()` | Removes spaces from both ends of a string | `" hello ".strip()` → `'hello'` |
# | `lstrip()` | Removes spaces from the left side | `" hello".lstrip()` → `'hello'` |
# | `rstrip()` | Removes spaces from the right side | `"hello ".rstrip()` → `'hello'` |
# | `replace()` | Replaces one substring with another | `"I like cats".replace("cats", "dogs")` → `'I like dogs'` |
# | `split()` | Splits a string into a list | `"apple,banana,mango".split(",")` → `['apple', 'banana', 'mango']` |
# | `join()` | Joins items in a list into a string | `"-".join(["a", "b", "c"])` → `'a-b-c'` |
# | `find()` | Finds the position of a substring | `"Python".find("t")` → `2` |
# | `index()` | Finds the position of a substring (raises error if not found) | `"Python".index("t")` → `2` |
# | `count()` | Counts how many times a value appears | `"banana".count("a")` → `3` |
# | `startswith()` | Checks if a string starts with a value | `"Python".startswith("Py")` → `True` |
# | `endswith()` | Checks if a string ends with a value | `"report.pdf".endswith(".pdf")` → `True` |
# | `isalpha()` | Checks if all characters are letters | `"Python".isalpha()` → `True` |
# | `isdigit()` | Checks if all characters are digits | `"12345".isdigit()` → `True` |
# | `isalnum()` | Checks if all characters are letters or numbers | `"Python123".isalnum()` → `True` |
# | `islower()` | Checks if all characters are lowercase | `"hello".islower()` → `True` |
# | `isupper()` | Checks if all characters are uppercase | `"HELLO".isupper()` → `True` |
#
# ---
#
# ## Practical Examples
#
# ### Example 1: Convert Text to Uppercase
#
# ```python
# name = "collins"
# print(name.upper())

# %% [markdown]
# # Replace a Word

# %%
text = "I love Java"
print(text.replace("Java", "Python"))

# %% [markdown]
# # Split a Sentence

# %%
sentence = "Apple Banana Mango"
fruits = sentence.split()
print(fruits)

# %% [markdown]
# # Count Occurrences

# %%
word = "banana"
print(word.count("a"))

# %% [markdown]
# # Check File Extension

# %%
filename = "report.pdf"
print(filename.endswith(".pdf"))

# %% [markdown]
# # Join List Items

# %%
items = ["Python", "Java", "C++"]
print(", ".join(items))

# %% [markdown]
# # String Concatenation
#
# To concatenate, or combine, two strings you can use the + operator.

# %%
a = "Hello"
b = "World"
c = a + b
print(c)

# %% [markdown]
# # 🎉 Congratulations! You've Successfully Completed the Roadmap to Becoming a Professional Python Developer (Lab 1)
#
# You have successfully completed the foundational topics in Python programming. These concepts form the building blocks for developing more advanced Python applications.
#
# ## 📚 What You Have Learned So Far
#
# 1. **Python Syntax**
# 2. **Variables and Data Types**
# 3. **String Indexing and Slicing**
# 4. **Python Operators**
#    - Arithmetic Operators
#    - Comparison Operators
#    - Logical Operators
#    - Assignment Operators
#    - Bitwise Operators
#    - Identity Operators
#    - Membership Operators
# 5. **Input and Output**
# 6. **String Methods and Manipulation**
#
# ## 🏆 Great Job!
#
# By mastering these fundamentals, you have taken the first important step toward becoming a professional Python developer. Continue practicing the concepts and examples covered in this lab to strengthen your understanding.
#
# ## 🚀 Next Week: Lab 2
#
# We will begin **Conditional Statements in Python**, where you will learn how to make decisions in your programs using:
#
# - `if` statements
# - `if...else` statements
# - `if...elif...else` statements
# - Nested conditions
# - Practical decision-making applications
#
# ## 📖 Preparation
#
# To get ahead, you can explore and familiarize yourself with Conditional Statements before our next session using the resource below:
#
# **Resource Link:**
# *[Link](https://docs.python.org/3/library/string.html)*
#
# ---
#
# ### Keep Practicing!
#
# > "The best way to learn programming is by writing code every day."
#
# See you in **Lab 2**! 🎯🐍
