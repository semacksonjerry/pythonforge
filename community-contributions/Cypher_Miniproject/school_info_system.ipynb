# %%
full_name = str(input("Enter your full name: "))
age = int(input("Enter your age: "))
school = str(input("Enter your school name: "))
subject = str(input("Enter your favorite subject: "))

print(f"=======STUDENT INFORMATION=======")
print(f"Name:                           {full_name}")
print(f"Age:                            {age}")
print(f"School:                         {school}")
print(f"Favorite Subject:               {subject}")

print(f"Name in uppercase:              {full_name.upper()}")

print(f"First 3 characters:             {full_name[:3]}")

print(f"Last 3 characters:              {full_name[-3:]}")

print(f"Your age after 5 years:         {age + 5}")

print(f"Total characters in your name:  {len(full_name)}")
# Out:
# =======STUDENT INFORMATION=======
# Name:                           Cypher
# Age:                            30
# School:                         UCC
# Favorite Subject:               computing
# Name in uppercase:              CYPHER
# First 3 characters:             Cyp
# Last 3 characters:              her
# Your age after 5 years:         35
# Total characters in your name:  6
